# %%
# !pip install chess
import sys
# !{sys.executable} -m pip install tensorflow==2.10
# !pip install tensorflow
import tensorflow as tf
import chess, chess.engine, os, stat
import random
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.10 (from versions: 2.20.0rc0, 2.20.0, 2.21.0rc0, 2.21.0rc1, 2.21.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for tensorflow==2.10
#
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
# !pip install stockfish
from stockfish import Stockfish
import os
print(os.path)

engine_path = r"C:\Users\llsad\Downloads\stockfish-windows-x86-64-avx2\stockfish\stockfish-windows-x86-64-avx2.exe"
sf = Stockfish(engine_path, parameters={"Threads": 1, "Hash": 256})
sf.set_depth(2)           
sf.set_skill_level(0)
sf.get_engine_parameters()
# Out:
# ...
# <module 'ntpath' (frozen)>
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# {'Debug Log File': '',
#  'Threads': 1,
#  'Hash': 256,
#  'Ponder': False,
#  'MultiPV': 1,
#  'Skill Level': 0,
#  'Move Overhead': 10,
#  'Slow Mover': 100,
#  'UCI_Chess960': False,
#  'UCI_LimitStrength': False,
#  'UCI_Elo': 1350,
#  'Contempt': 0,
#  'Min Split Depth': 0,
#  'Minimum Thinking Time': 20}

# %%
import importlib
import policy
importlib.reload(policy)
from policy import *
# Out:
# POLICY V7
# POLICY V7

# %%
# games = load_json("1400-1500_games.json")
games = load_json("1400-1500_games.json", n = 1000)
print('done')
# Out:
# Loading games:   1%|▋                                                                                                                       | 1000/163266 [00:02<05:58, 452.37it/s]
# done

# %%
agent = Agent("")
agent.train(games)
# Out:
# Agent V2
# []
# 1994/1994 ━━━━━━━━━━━━━━━━━━━━ 836s 412ms/step - accuracy: 0.0838 - loss: 0.0023

# %%
board = chess.Board()
def stockfish_move():
    sf.set_fen_position(board.fen())
    move = sf.get_best_move()
    board.push(chess.Move.from_uci(move))
def agent_move():
    move = agent.act(board)
    board.push(move)

# %%
NUM_GAMES = 5

games_data = []
for i in tqdm(range(NUM_GAMES), desc="Playing games"):
    board = chess.Board()
    game = chess.pgn.Game()
    game.headers.update({
        "Event": "Agent vs Stockfish",
        "Round": str(i + 1),
        "White": f"Mimic Agent of {agent.id}",
        "Black": "Stockfish",
    })

    node = game
    while not board.is_game_over():
        if board.turn == chess.WHITE:
            res = agent.act(board, sf = sf)
            move, blocked = res[0], res[1]
            print(blocked)
            if move is None:
                break
        else:
            sf.set_fen_position(board.fen())
            best = sf.get_best_move_time(1)
            if best is None:
                break
            move = chess.Move.from_uci(best)
        board.push(move)
        node = node.add_variation(move)

    game.headers["Result"] = board.result()
    games_data.append(game)


safe_id = str(agent.id).replace(" ", "_").lower()
with open(f"{safe_id}_agent_vs_stockfish.pgn", "w") as f:
    for game in games_data:
        print(game, file=f, end="\n\n")
# Out:
# Playing games:   0%|                                                                                                                                         | 0/5 [00:00<?, ?it/s]
# selecting move <stockfish.models.Stockfish object at 0x0000015C6DDB9D30>
# 27 14 r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B N R g1f3
# 0
# C:\Users\llsad\OneDrive\Documents\GitHub\DS440-Capstone\policy.py:137: UserWarning: Note that even though you've set Stockfish to play on a weaker elo or skill level, get_evaluation will still return full strength Stockfish's evaluation of the position.
#   before = sf.get_evaluation()['value']
# C:\Users\llsad\OneDrive\Documents\GitHub\DS440-Capstone\policy.py:143: UserWarning: Note that even though you've set Stockfish to play on a weaker elo or skill level, get_evaluation will still return full strength Stockfish's evaluation of the position.
# ...
